# %% [markdown]
# <table>
# <tr>
# <td width = "150px"><img src="files/SnakeyTitle.png"/></td>
# <td width="500px"><center>
# <h1>Lets Get Started</h1>
# </center></td>
# <td width='150px'><img src="files/AuthorCredit.png"/></td>
# </tr>
# </table>

# %%
import pandas as pd 
import numpy as np

# %%
md_employment = pd.read_csv("../data/Employment_Figures.csv")

# %%
national_unemployment = pd.read_excel(
    '../data/national_unemployment.xlsx', sheet="BLS Data Series", index_col='Year')
national_unemployment
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep   Oct  Nov  Dec  Annual
# Year
# 2004  5.7  5.6  5.8  5.6  5.6  5.6  5.5  5.4  5.4   5.5  5.4  5.4     NaN
# 2005  5.3  5.4  5.2  5.2  5.1  5.0  5.0  4.9  5.0   5.0  5.0  4.9     NaN
# 2006  4.7  4.8  4.7  4.7  4.6  4.6  4.7  4.7  4.5   4.4  4.5  4.4     NaN
# 2007  4.6  4.5  4.4  4.5  4.4  4.6  4.7  4.6  4.7   4.7  4.7  5.0     NaN
# 2008  5.0  4.9  5.1  5.0  5.4  5.6  5.8  6.1  6.1   6.5  6.8  7.3     NaN
# 2009  7.8  8.3  8.7  9.0  9.4  9.5  9.5  9.6  9.8  10.0  9.9  9.9     NaN
# 2010  9.7  9.8  9.9  9.9  9.6  9.4  9.5  9.5  9.5   9.5  9.8  9.4     NaN
# 2011  9.1  9.0  9.0  9.1  9.0  9.1  9.0  9.0  9.0   8.8  8.6  8.5     NaN
# 2012  8.2  8.3  8.2  8.2  8.2  8.2  8.2  8.1  7.8   7.8  7.8  7.9     NaN
# 2013  7.9  7.7  7.5  7.5  7.5  7.5  7.3  7.2  7.2   7.2  7.0  6.7     NaN
# 2014  6.6  6.7  6.7  6.3  6.3  6.1  6.2  NaN  NaN   NaN  NaN  NaN     NaN

# %%
md_employment.dtypes
# Out:
# Year                                                   int64
# Month                                                 object
# National Unemployment Rate                           float64
# Maryland Unemployment Rate                           float64
# National Jobs Created/Lost                             int64
# Maryland Jobs Created/Lost                             int64
# National Jobs                                          int64
# Maryland Jobs                                          int64
# Maryland Civilian Labor Force                          int64
# Maryland Employment                                    int64
# Maryland Unemployment                                  int64
# Maryland Job Growth Since Post Recession Bottom      float64
# Jobs Recovered Goal (to Reach Pre-Recession Peak)    float64
# % Jobs Recovered (Maryland)                           object
# dtype: object

# %%
md_employment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 0 to 135
# Data columns (total 14 columns):
# Year                                                 136 non-null int64
# Month                                                136 non-null object
# National Unemployment Rate                           136 non-null float64
# Maryland Unemployment Rate                           136 non-null float64
# National Jobs Created/Lost                           136 non-null int64
# Maryland Jobs Created/Lost                           136 non-null int64
# National Jobs                                        136 non-null int64
# Maryland Jobs                                        136 non-null int64
# Maryland Civilian Labor Force                        136 non-null int64
# Maryland Employment                                  136 non-null int64
# Maryland Unemployment                                136 non-null int64
# Maryland Job Growth Since Post Recession Bottom      51 non-null float64
# Jobs Recovered Goal (to Reach Pre-Recession Peak)    51 non-null float64
# % Jobs Recovered (Maryland)                          51 non-null object
# dtypes: float64(4), int64(8), object(2)

# %%
md_employment.tail()
# Out:
#      Year   Month  National Unemployment Rate  Maryland Unemployment Rate  \
# 131  2013  Dec-13                         6.7                         6.1
# 132  2014  Jan-14                         6.6                         5.8
# 133  2014  Feb-14                         6.7                         5.6
# 134  2014  Mar-14                         6.7                         5.6
# 135  2014  Apr-14                         6.3                         5.5
#
#      National Jobs Created/Lost  Maryland Jobs Created/Lost  National Jobs  \
# 131                       84000                        4300      137395000
# 132                      144000                       -6100      137539000
# 133                      222000                        1000      137761000
# 134                      203000                        3500      137964000
# 135                      288000                        9300      138252000
#
#      Maryland Jobs  Maryland Civilian Labor Force  Maryland Employment  \
# 131        2609300                        3107008              2919013
# 132        2603200                        3109348              2927735
# 133        2604200                        3109151              2933498
# 134        2606500                        3108307              2934224
# 135        2617000                        3110695              2938947
#
#      Maryland Unemployment  Maryland Job Growth Since Post Recession Bottom  \
# 131                 187995                                           141400
# 132                 181613                                           135300
# 133                 175653                                           136300
# 134                 174083                                           139800
# 135                 171748                                           149100
#
#      Jobs Recovered Goal (to Reach Pre-Recession Peak)  \
# 131                                             148000
# 132                                             148000
# 133                                             148000
# 134                                             148000
# 135                                             148000
#
#     % Jobs Recovered (Maryland)
# 131                       95.5%
# 132                       91.4%
# 133                       92.1%
# 134                       93.6%
# 135                      100.0%

# %%
md_employment.ix[5]
# Out:
# Year                                                      2003
# Month                                                   Jun-03
# National Unemployment Rate                                 6.3
# Maryland Unemployment Rate                                 4.6
# National Jobs Created/Lost                               -3000
# Maryland Jobs Created/Lost                                3600
# National Jobs                                        129943000
# Maryland Jobs                                          2488600
# Maryland Civilian Labor Force                          2882930
# Maryland Employment                                    2750986
# Maryland Unemployment                                   131944
# Maryland Job Growth Since Post Recession Bottom            NaN
# Jobs Recovered Goal (to Reach Pre-Recession Peak)          NaN
# % Jobs Recovered (Maryland)                                NaN
# Name: 5, dtype: object
