# %% [markdown]
# ## Pandas Merge and Join Dataframes: NYC 311 Calls

# %%
The NYC 311 Data Set is updated on a daily basis and is made of over 7 million rows! This is the biggest

# %%
## Import Pandas and other relevant packages. 

import pandas as pd # the pandas package
import numpy as np

# %%
rat_sightings = pd.read_csv('../data/rat_sightings.csv')
rat_sightings.head()
# Out:
#    Unique Key            Created Date Closed Date Agency  \
# 0    28794361  09/02/2014 12:22:19 AM         NaN  DOHMH
# 1    28795504  09/02/2014 12:09:01 AM         NaN  DOHMH
# 2    28792770  09/01/2014 11:48:11 PM         NaN  DOHMH
# 3    28795090  09/01/2014 09:26:35 PM         NaN  DOHMH
# 4    28795455  09/01/2014 07:12:25 PM         NaN  DOHMH
#
#                                Agency Name Complaint Type    Descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 4  Department of Health and Mental Hygiene         Rodent  Rat Sighting
#
#              Location Type  Incident Zip      Incident Address  \
# 0  3+ Family Apt. Building         10452  1605 TOWNSEND AVENUE
# ...

# %%
rat_sightings[['City', 'Agency']]
rat_sightings.head()
# Out:
#    Unique Key            Created Date Closed Date Agency  \
# 0    28794361  09/02/2014 12:22:19 AM         NaN  DOHMH
# 1    28795504  09/02/2014 12:09:01 AM         NaN  DOHMH
# 2    28792770  09/01/2014 11:48:11 PM         NaN  DOHMH
# 3    28795090  09/01/2014 09:26:35 PM         NaN  DOHMH
# 4    28795455  09/01/2014 07:12:25 PM         NaN  DOHMH
#
#                                Agency Name Complaint Type    Descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 4  Department of Health and Mental Hygiene         Rodent  Rat Sighting
#
#              Location Type  Incident Zip      Incident Address  \
# 0  3+ Family Apt. Building         10452  1605 TOWNSEND AVENUE
# ...

# %%
#preprocessing
rat_sightings.loc[rat_sightings['City'] == 'BRONX'][['City', 'Created Date','Agency']]
#rat = rat_sightings[['City']]
#rat
# Out:
#         City Agency
# 0      BRONX  DOHMH
# 2      BRONX  DOHMH
# 3      BRONX  DOHMH
# 6      BRONX  DOHMH
# 7      BRONX  DOHMH
# 18     BRONX  DOHMH
# 20     BRONX  DOHMH
# 22     BRONX  DOHMH
# 59     BRONX  DOHMH
# 60     BRONX  DOHMH
# 72     BRONX  DOHMH
# 73     BRONX  DOHMH
# 74     BRONX  DOHMH
# 76     BRONX  DOHMH
# 86     BRONX  DOHMH
# 87     BRONX  DOHMH
# 91     BRONX  DOHMH
# 92     BRONX  DOHMH
# 96     BRONX  DOHMH
# 98     BRONX  DOHMH
# 103    BRONX  DOHMH
# 111    BRONX  DOHMH
# 117    BRONX  DOHMH
# 119    BRONX  DOHMH
# 121    BRONX  DOHMH
# 124    BRONX  DOHMH
# 125    BRONX  DOHMH
# 134    BRONX  DOHMH
# 141    BRONX  DOHMH
# 150    BRONX  DOHMH
# ...      ...    ...
# 50772  BRONX  DOHMH
# 50777  BRONX  DOHMH
# 50778  BRONX  DOHMH
# 50779  BRONX  DOHMH
# 50781  BRONX  DOHMH
# 50783  BRONX  DOHMH
# 50786  BRONX  DOHMH
# 50791  BRONX  DOHMH
# 50792  BRONX  DOHMH
# 50793  BRONX  DOHMH
# 50806  BRONX  DOHMH
# 50814  BRONX  DOHMH
# 50828  BRONX  DOHMH
# ...

# %%
national_unemployment = pd.read_excel('../data/national_unemployment.xlsx', sheet="BLS Data Series", index_col='Year')
national_unemployment.head()
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  Annual
# Year
# 2004  5.7  5.6  5.8  5.6  5.6  5.6  5.5  5.4  5.4  5.5  5.4  5.4     NaN
# 2005  5.3  5.4  5.2  5.2  5.1  5.0  5.0  4.9  5.0  5.0  5.0  4.9     NaN
# 2006  4.7  4.8  4.7  4.7  4.6  4.6  4.7  4.7  4.5  4.4  4.5  4.4     NaN
# 2007  4.6  4.5  4.4  4.5  4.4  4.6  4.7  4.6  4.7  4.7  4.7  5.0     NaN
# 2008  5.0  4.9  5.1  5.0  5.4  5.6  5.8  6.1  6.1  6.5  6.8  7.3     NaN

# %%
## Concat Whole datasets

md_and_national_ds = pd.concat([md_employment, national_unemployment], ignore_index=True)
#md_and_national_ds = pd.merge(md_employment, national_unemployment, on=key)

md_and_national_ds

# %% [markdown]
# ## Replace NaN with 0
# This is just one out of many ways of dealing with NaN

# %%
md_and_national_ds.fillna(0)

# %%
## The Problem in this case is not NaN
The issue really lies in our merge strategy and not NaN.
